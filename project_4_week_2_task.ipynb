# %% [markdown]
# # **Feature Extraction and Price Prediction for Mobile Phones**

# %% [markdown]
# **Problem Statement**
# - I worked for a prominent organization that specializes in selling mobile phones. The organization is keen to enhance its pricing strategy by gaining a deeper understanding of the key features that influence the prices of mobile phones in today's highly competitive market. my objective is to build a predictive model that can accurately estimate the price of a mobile phone based on its features. To achieve this, you'll perform a feature extraction analysis to identify the most influential features.

# %% [markdown]
# **Project Description:**
# - In this project, I worked with a dataset that contains detailed information about various mobile phones, including their model, color, memory, RAM, battery capacity, rear camera specifications, front camera specifications, presence of AI lens, mobile height, processor, and, most importantly, the price.
# - My goal is to develop a predictive model for mobile phone prices.

# %% [markdown]
# **Data Wrangling**
# - It convert and format raw data to usable format down to data science pipeline

# %% [markdown]
# # **Data Exploration:**

# %% [markdown]
# **Import Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import seaborn as sns
import warnings

# %% [markdown]
# **Loading the given Dataset**

# %%
data=pd.read_csv('/content/Processed_Flipdata - Processed_Flipdata (1).csv')

# %%
data # to check data
# Out:
#      Unnamed: 0                  Model          Colour  Memory  RAM  Battery_  \
# 0             0        Infinix SMART 7     Night Black      64    4      6000
# 1             1        Infinix SMART 7      Azure Blue      64    4      6000
# 2             2           MOTOROLA G32    Mineral Gray     128    8      5000
# 3             3               POCO C50      Royal Blue      32    2      5000
# 4             4        Infinix HOT 30i        Marigold     128    8      5000
# ..          ...                    ...             ...     ...  ...       ...
# 536         637  SAMSUNG Galaxy S23 5G           Cream     256    8      3900
# 537         638               LAVA Z21            Cyan      32    2      3100
# 538         639         Tecno Spark 8T  Turquoise Cyan      64    4      5000
# 539         641  SAMSUNG Galaxy A54 5G    Awesome Lime     128    8      5000
# 540         642               OPPO A77        Sky Blue     128    4      5000
#
#     Rear Camera Front Camera  AI Lens  Mobile Height  \
# 0          13MP          5MP        1          16.76
# 1          13MP          5MP        1          16.76
# 2          50MP         16MP        0          16.64
# 3           8MP          5MP        0          16.56
# 4          50MP          5MP        1          16.76
# ..          ...          ...      ...            ...
# 536        50MP         12MP        0          15.49
# 537         5MP          2MP        0          12.70
# 538        50MP          8MP        0          16.76
# 539        50MP         32MP        0          16.26
# 540        50MP          8MP        0          16.66
#
#                       Processor_   Prize
# 0     Unisoc Spreadtrum SC9863A1   7,299
# 1     Unisoc Spreadtrum SC9863A1   7,299
# 2        Qualcomm Snapdragon 680  11,999
# 3             Mediatek Helio A22   5,649
# 4                            G37   8,999
# ..                           ...     ...
# 536  Qualcomm Snapdragon 8 Gen 2  79,999
# 537                    Octa Core   5,998
# 538           MediaTek Helio G35   9,990
# 539      Exynos 1380, Octa Core   38,999
# 540           Mediatek Helio G35  15,999
#
# [541 rows x 12 columns]

# %% [markdown]
# **Check the shape of data**

# %%
data.shape[0]#only no of rows
# Out:
# 541

# %%
data.shape[1]#only no of columns
# Out:
# 12

# %% [markdown]
# **Check first five Rows**

# %%
data.head()
# Out:
#    Unnamed: 0            Model        Colour  Memory  RAM  Battery_  \
# 0           0  Infinix SMART 7   Night Black      64    4      6000
# 1           1  Infinix SMART 7    Azure Blue      64    4      6000
# 2           2     MOTOROLA G32  Mineral Gray     128    8      5000
# 3           3         POCO C50    Royal Blue      32    2      5000
# 4           4  Infinix HOT 30i      Marigold     128    8      5000
#
#   Rear Camera Front Camera  AI Lens  Mobile Height  \
# 0        13MP          5MP        1          16.76
# 1        13MP          5MP        1          16.76
# 2        50MP         16MP        0          16.64
# 3         8MP          5MP        0          16.56
# 4        50MP          5MP        1          16.76
#
#                    Processor_   Prize
# 0  Unisoc Spreadtrum SC9863A1   7,299
# 1  Unisoc Spreadtrum SC9863A1   7,299
# 2     Qualcomm Snapdragon 680  11,999
# 3          Mediatek Helio A22   5,649
# 4                         G37   8,999

# %% [markdown]
# **Check all the column names of dataset**

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Model', 'Colour', 'Memory', 'RAM', 'Battery_',
#        'Rear Camera', 'Front Camera', 'AI Lens', 'Mobile Height', 'Processor_',
#        'Prize'],
#       dtype='object')

# %%
# Number of uniqe elements in each columns
unique = data.nunique()
unique.to_frame().T
# Out:
#    Unnamed: 0  Model  Colour  Memory  RAM  Battery_  Rear Camera  \
# 0         541    187     275       5    5        37           14
#
#    Front Camera  AI Lens  Mobile Height  Processor_  Prize
# 0            13        2             38         123    158

# %%
data.rename(columns={'prize': 'Price'}, inplace=True)

# %% [markdown]
# **check info of dataset**

# %%
# Getting the informaatin of the data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541 entries, 0 to 540
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     541 non-null    int64
#  1   Model          541 non-null    object
#  2   Colour         541 non-null    object
#  3   Memory         541 non-null    int64
#  4   RAM            541 non-null    int64
#  5   Battery_       541 non-null    int64
#  6   Rear Camera    541 non-null    object
#  7   Front Camera   541 non-null    object
#  8   AI Lens        541 non-null    int64
#  9   Mobile Height  541 non-null    float64
#  10  Processor_     541 non-null    object
#  11  Prize          541 non-null    object
# dtypes: float64(1), int64(5), object(6)
# memory usage: 50.8+ KB

# %% [markdown]
# **Descriptive Statistics**

# %% [markdown]
# **Summary Statistics**
# - **Measure of central Tendancy**
# - **Mean**: Mean is the average of all values
# - **mode**: Median is the middle value when data is sorted.
# -**Median** : Mode is the most frequently occurring value in the dataset.
# -**Describe()** is used to view some basic statistical details like percentile, mean, std, etc. of a data frame or a series of numeric values.

# %%
data.describe(include='all')
# Out:
#         Unnamed: 0     Model  Colour      Memory         RAM     Battery_  \
# count   541.000000       541     541  541.000000  541.000000   541.000000
# unique         NaN       187     275         NaN         NaN          NaN
# top            NaN  vivo Y16  Yellow         NaN         NaN          NaN
# freq           NaN         9      12         NaN         NaN          NaN
# mean    289.711645       NaN     NaN  110.550832    5.397412  4871.587800
# std     182.359185       NaN     NaN   60.600694    1.984923   780.148862
# min       0.000000       NaN     NaN   16.000000    2.000000   800.000000
# 25%     135.000000       NaN     NaN   64.000000    4.000000  5000.000000
# 50%     273.000000       NaN     NaN  128.000000    6.000000  5000.000000
# 75%     434.000000       NaN     NaN  128.000000    8.000000  5000.000000
# max     642.000000       NaN     NaN  256.000000    8.000000  7000.000000
#
#        Rear Camera Front Camera     AI Lens  Mobile Height  \
# count          541          541  541.000000     541.000000
# unique          14           13         NaN            NaN
# top           50MP         16MP         NaN            NaN
# freq           260          164         NaN            NaN
# mean           NaN          NaN    0.062847      16.431201
# std            NaN          NaN    0.242911       2.523553
# min            NaN          NaN    0.000000       4.500000
# 25%            NaN          NaN    0.000000      16.510000
# 50%            NaN          NaN    0.000000      16.710000
# 75%            NaN          NaN    0.000000      16.940000
# max            NaN          NaN    1.000000      41.940000
#
#                      Processor_   Prize
# count                       541     541
# unique                      123     158
# top     Qualcomm Snapdragon 680  15,999
# freq                         33      23
# mean                        NaN     NaN
# std                         NaN     NaN
# min                         NaN     NaN
# 25%                         NaN     NaN
# 50%                         NaN     NaN
# 75%                         NaN     NaN
# max                         NaN     NaN

# %%
data.dtypes
# Out:
# Unnamed: 0         int64
# Model             object
# Colour            object
# Memory             int64
# RAM                int64
# Battery_           int64
# Rear Camera       object
# Front Camera      object
# AI Lens            int64
# Mobile Height    float64
# Processor_        object
# Prize             object
# dtype: object

# %% [markdown]
# **It filters columns that have object data types, which typically represent strings or categorical variables.**

# %%
cat_col=data.select_dtypes(include='object')

# %%
cat_col
# Out:
#                      Model          Colour Rear Camera Front Camera  \
# 0          Infinix SMART 7     Night Black        13MP          5MP
# 1          Infinix SMART 7      Azure Blue        13MP          5MP
# 2             MOTOROLA G32    Mineral Gray        50MP         16MP
# 3                 POCO C50      Royal Blue         8MP          5MP
# 4          Infinix HOT 30i        Marigold        50MP          5MP
# ..                     ...             ...         ...          ...
# 536  SAMSUNG Galaxy S23 5G           Cream        50MP         12MP
# 537               LAVA Z21            Cyan         5MP          2MP
# 538         Tecno Spark 8T  Turquoise Cyan        50MP          8MP
# 539  SAMSUNG Galaxy A54 5G    Awesome Lime        50MP         32MP
# 540               OPPO A77        Sky Blue        50MP          8MP
#
#                       Processor_   Prize
# 0     Unisoc Spreadtrum SC9863A1   7,299
# 1     Unisoc Spreadtrum SC9863A1   7,299
# 2        Qualcomm Snapdragon 680  11,999
# 3             Mediatek Helio A22   5,649
# 4                            G37   8,999
# ..                           ...     ...
# 536  Qualcomm Snapdragon 8 Gen 2  79,999
# 537                    Octa Core   5,998
# 538           MediaTek Helio G35   9,990
# 539      Exynos 1380, Octa Core   38,999
# 540           Mediatek Helio G35  15,999
#
# [541 rows x 6 columns]

# %% [markdown]
# **It filters columns that have int64,float data types, which typically represent numerical features**

# %%
num_col=data.select_dtypes(include=['int64', 'float'])

# %%
num_col
# Out:
#      Unnamed: 0  Memory  RAM  Battery_  AI Lens  Mobile Height
# 0             0      64    4      6000        1          16.76
# 1             1      64    4      6000        1          16.76
# 2             2     128    8      5000        0          16.64
# 3             3      32    2      5000        0          16.56
# 4             4     128    8      5000        1          16.76
# ..          ...     ...  ...       ...      ...            ...
# 536         637     256    8      3900        0          15.49
# 537         638      32    2      3100        0          12.70
# 538         639      64    4      5000        0          16.76
# 539         641     128    8      5000        0          16.26
# 540         642     128    4      5000        0          16.66
#
# [541 rows x 6 columns]

# %% [markdown]
# -**Measure of dispersion**: Measures of Dispersion are used to represent the scattering of data. These are the numbers that show the various aspects of the data spread across various parameters.
#  - **Range**: It is defined as the difference between the largest and the smallest value in the distribution.
#  -**Starndard deviation**: It is the square root of the arithmetic average of the square of the deviations measured from the mean.
#  -**percentiles**:  How many of the values are less than the given percentile

# %%
data['Prize'].unique()
# Out:
# array(['7,299', '11,999', '5,649', '8,999', '7,999', '9,499', '10,699',
#        '6,999', '15,999', '13,999', '12,999', '6,199', '6,599', '7,749',
#        '9,699', '9,999', '10,999', '20,999', '15,499', '18,999', '12,499',
#        '10,499', '14,490', '16,999', '6,499', '5,999', '6,299', '16,499',
#        '14,499', '13,490', '19,999', '1,449', '1,849', '1,422', '29,999',
#        '1,299', '17,999', '11,499', '2,615', '28,999', '23,999', '14,999',
#        '2,490', '7,961', '2,499', '11,248', '6,799', '13,499', '8,749',
#        '8,049', '1,375', '1,599', '7,499', '7,245', '26,999', '21,999',
#        '17,499', '21,499', '7,115', '49,999', '32,999', '8,499', '25,999',
#        '4,999', '3,549', '1,699', '920', '11,970', '1,199', '12,990',
#        '6,978', '7,370', '44,999', '8,995', '24,999', '11,249', '34,999',
#        '21,174', '43,999', '7,993', '8,069', '30,499', '30,999', '9,290',
#        '8,449', '8,495', '29,499', '20,998', '19,280', '8,649', '19,499',
#        '9,349', '8,288', '12,272', '6,794', '27,540', '27,877', '5,990',
#        '11,980', '11,349', '9,790', '28,298', '22,999', '7,049', '6,960',
#        '9,104', '36,999', '30,385', '19,990', '12,900', '8,990', '10,943',
#        '55,999', '13,489', '11,209', '16,988', '12,989', '7,190', '7,990',
#        '27,999', '19,397', '10,989', '16,990', '29,990', '38,920',
#        '9,387', '29,790', '5,799', '10,890', '10,548', '32,299', '40,999',
#        '11,490', '12,599', '31,989', '41,199', '7,199', '8,940', '19,979',
#        '23,390', '14,385', '80,999', '30,874', '35,999', '10,799',
#        '11,762', '18,990', '29,418', '33,367', '7,280', '34,688', '8,460',
#        '20,890', '53,999', '79,999', '5,998', '9,990', '38,999'],
#       dtype=object)

# %%
data['Prize'].nunique()
# Out:
# 158

# %%
data['Prize'].value_counts()
# Out:
# Prize
# 15,999    23
# 9,999     22
# 16,999    21
# 8,999     20
# 23,999    19
#           ..
# 20,998     1
# 29,499     1
# 8,495      1
# 8,449      1
# 38,999     1
# Name: count, Length: 158, dtype: int64

# %%
numerical_summary = num_col.describe().transpose()
palette = sns.color_palette("viridis", as_cmap=True)
numerical_summary.style.background_gradient(cmap=palette)
# Out:
# <style type="text/css">
# #T_83957_row0_col0, #T_83957_row0_col3, #T_83957_row1_col0, #T_83957_row2_col0, #T_83957_row2_col1, #T_83957_row2_col2, #T_83957_row2_col3, #T_83957_row2_col4, #T_83957_row2_col5, #T_83957_row2_col6, #T_83957_row2_col7, #T_83957_row3_col0, #T_83957_row4_col0, #T_83957_row4_col1, #T_83957_row4_col2, #T_83957_row4_col3, #T_83957_row4_col4, #T_83957_row4_col5, #T_83957_row4_col6, #T_83957_row4_col7, #T_83957_row5_col0, #T_83957_row5_col1, #T_83957_row5_col2, #T_83957_row5_col4, #T_83957_row5_col5, #T_83957_row5_col6 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_83957_row0_col1 {
#   background-color: #481769;
#   color: #f1f1f1;
# }
# #T_83957_row0_col2 {
#   background-color: #3d4d8a;
#   color: #f1f1f1;
# }
# #T_83957_row0_col4, #T_83957_row1_col5, #T_83957_row1_col6 {
#   background-color: #460a5d;
#   color: #f1f1f1;
# }
# #T_83957_row0_col5 {
#   background-color: #481467;
#   color: #f1f1f1;
# }
# #T_83957_row0_col6 {
#   background-color: #482071;
#   color: #f1f1f1;
# }
# #T_83957_row0_col7 {
#   background-color: #482173;
#   color: #f1f1f1;
# }
# #T_83957_row1_col1, #T_83957_row1_col3 {
#   background-color: #46085c;
#   color: #f1f1f1;
# }
# #T_83957_row1_col2 {
#   background-color: #481c6e;
#   color: #f1f1f1;
# }
# #T_83957_row1_col4 {
#   background-color: #450559;
#   color: #f1f1f1;
# }
# #T_83957_row1_col7 {
#   background-color: #470e61;
#   color: #f1f1f1;
# }
# #T_83957_row3_col1, #T_83957_row3_col2, #T_83957_row3_col3, #T_83957_row3_col4, #T_83957_row3_col5, #T_83957_row3_col6, #T_83957_row3_col7 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_83957_row5_col3, #T_83957_row5_col7 {
#   background-color: #440256;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_83957" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_83957_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_83957_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_83957_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_83957_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_83957_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_83957_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_83957_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_83957_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_83957_level0_row0" class="row_heading level0 row0" >Unnamed: 0</th>
#       <td id="T_83957_row0_col0" class="data row0 col0" >541.000000</td>
#       <td id="T_83957_row0_col1" class="data row0 col1" >289.711645</td>
#       <td id="T_83957_row0_col2" class="data row0 col2" >182.359185</td>
#       <td id="T_83957_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_83957_row0_col4" class="data row0 col4" >135.000000</td>
#       <td id="T_83957_row0_col5" class="data row0 col5" >273.000000</td>
#       <td id="T_83957_row0_col6" class="data row0 col6" >434.000000</td>
#       <td id="T_83957_row0_col7" class="data row0 col7" >642.000000</td>
#     </tr>
#     <tr>
#       <th id="T_83957_level0_row1" class="row_heading level0 row1" >Memory</th>
#       <td id="T_83957_row1_col0" class="data row1 col0" >541.000000</td>
#       <td id="T_83957_row1_col1" class="data row1 col1" >110.550832</td>
#       <td id="T_83957_row1_col2" class="data row1 col2" >60.600694</td>
#       <td id="T_83957_row1_col3" class="data row1 col3" >16.000000</td>
#       <td id="T_83957_row1_col4" class="data row1 col4" >64.000000</td>
#       <td id="T_83957_row1_col5" class="data row1 col5" >128.000000</td>
#       <td id="T_83957_row1_col6" class="data row1 col6" >128.000000</td>
#       <td id="T_83957_row1_col7" class="data row1 col7" >256.000000</td>
#     </tr>
#     <tr>
#       <th id="T_83957_level0_row2" class="row_heading level0 row2" >RAM</th>
#       <td id="T_83957_row2_col0" class="data row2 col0" >541.000000</td>
#       <td id="T_83957_row2_col1" class="data row2 col1" >5.397412</td>
#       <td id="T_83957_row2_col2" class="data row2 col2" >1.984923</td>
#       <td id="T_83957_row2_col3" class="data row2 col3" >2.000000</td>
#       <td id="T_83957_row2_col4" class="data row2 col4" >4.000000</td>
#       <td id="T_83957_row2_col5" class="data row2 col5" >6.000000</td>
#       <td id="T_83957_row2_col6" class="data row2 col6" >8.000000</td>
#       <td id="T_83957_row2_col7" class="data row2 col7" >8.000000</td>
#     </tr>
#     <tr>
#       <th id="T_83957_level0_row3" class="row_heading level0 row3" >Battery_</th>
#       <td id="T_83957_row3_col0" class="data row3 col0" >541.000000</td>
#       <td id="T_83957_row3_col1" class="data row3 col1" >4871.587800</td>
#       <td id="T_83957_row3_col2" class="data row3 col2" >780.148862</td>
#       <td id="T_83957_row3_col3" class="data row3 col3" >800.000000</td>
#       <td id="T_83957_row3_col4" class="data row3 col4" >5000.000000</td>
#       <td id="T_83957_row3_col5" class="data row3 col5" >5000.000000</td>
#       <td id="T_83957_row3_col6" class="data row3 col6" >5000.000000</td>
#       <td id="T_83957_row3_col7" class="data row3 col7" >7000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_83957_level0_row4" class="row_heading level0 row4" >AI Lens</th>
#       <td id="T_83957_row4_col0" class="data row4 col0" >541.000000</td>
#       <td id="T_83957_row4_col1" class="data row4 col1" >0.062847</td>
#       <td id="T_83957_row4_col2" class="data row4 col2" >0.242911</td>
#       <td id="T_83957_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_83957_row4_col4" class="data row4 col4" >0.000000</td>
#       <td id="T_83957_row4_col5" class="data row4 col5" >0.000000</td>
#       <td id="T_83957_row4_col6" class="data row4 col6" >0.000000</td>
#       <td id="T_83957_row4_col7" class="data row4 col7" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_83957_level0_row5" class="row_heading level0 row5" >Mobile Height</th>
#       <td id="T_83957_row5_col0" class="data row5 col0" >541.000000</td>
#       <td id="T_83957_row5_col1" class="data row5 col1" >16.431201</td>
#       <td id="T_83957_row5_col2" class="data row5 col2" >2.523553</td>
#       <td id="T_83957_row5_col3" class="data row5 col3" >4.500000</td>
#       <td id="T_83957_row5_col4" class="data row5 col4" >16.510000</td>
#       <td id="T_83957_row5_col5" class="data row5 col5" >16.710000</td>
#       <td id="T_83957_row5_col6" class="data row5 col6" >16.940000</td>
#       <td id="T_83957_row5_col7" class="data row5 col7" >41.940000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### **The range of values for each feature.**

# %%
# Check range for 'Memory'
if data['Memory'].dtype in ['int64', 'float64']:
    print(f"Memory: min = {data['Memory'].min()}, max = {data['Memory'].max()}")
else:
    print(f"Memory: unique values = {data['Memory'].unique()}")
# Out:
# Memory: min = 16, max = 256

# %%
 #Check range for 'RAM'
if data['RAM'].dtype in ['int64', 'float64']:
    print(f"RAM: min = {data['RAM'].min()}, max = {data['RAM'].max()}")
else:
    print(f"RAM: unique values = {data['RAM'].unique()}")
# Out:
# RAM: min = 2, max = 8

# %%
# Check range for 'Battery_'
if data['Battery_'].dtype in ['int64', 'float64']:
    print(f"Battery_: min = {data['Battery_'].min()}, max = {data['Battery_'].max()}")
else:
    print(f"Battery_: unique values = {data['Battery_'].unique()}")
# Out:
# Battery_: min = 800, max = 7000

# %%
# Check range for 'AI Lens'
if data['AI Lens'].dtype in ['int64', 'float64']:
    print(f"AI Lens: min = {data['AI Lens'].min()}, max = {data['AI Lens'].max()}")
else:
    print(f"AI Lens: unique values = {data['AI Lens'].unique()}")
# Out:
# AI Lens: min = 0, max = 1

# %%
# Check range for 'Mobile Height'
if data['Mobile Height'].dtype in ['int64', 'float64']:
    print(f"Mobile Height: min = {data['Mobile Height'].min()}, max = {data['Mobile Height'].max()}")
else:
    print(f"Mobile Height: unique values = {data['Mobile Height'].unique()}")
# Out:
# Mobile Height: min = 4.5, max = 41.94

# %%
# Check range for 'Model'
print(f"Model: unique values = {data['Model'].unique()}")
# Out:
# Model: unique values = ['Infinix SMART 7' 'MOTOROLA G32' 'POCO C50' 'Infinix HOT 30i' 'REDMI 10'
#  'SAMSUNG Galaxy F13' 'SAMSUNG Galaxy F04' 'POCO C51' 'MOTOROLA e13'
#  'vivo T2x 5G' 'Infinix Smart 7 HD' 'REDMI A1+' 'POCO C55' 'MOTOROLA g13'
#  'POCO M4 5G' 'MOTOROLA e32' 'vivo T2 5G' 'MOTOROLA G62 5G' 'POCO M5'
#  'realme C33 2023' 'SAMSUNG Galaxy F14 5G' 'MOTOROLA g73 5G' 'realme C30'
#  'POCO X5 5G' 'POCO M4 Pro' 'REDMI 11 Prime' 'realme C55'
#  'realme 10 Pro 5G' 'Micromax IN 2C' 'POCO M4 Pro 5G'
#  'realme Narzo 30 Pro 5G' 'micromax 2' 'Infinix Note 12 Pro 5G'
#  'SAMSUNG Galaxy F23 5G' 'micromax' 'MOTOROLA Edge 40' 'micromax 1'
#  'realme Narzo 30' 'Infinix NOTE 12i' 'realme 10' 'realme 8i' 'Micromax 3'
#  'Google Pixel 6a' 'Infinix HOT 20 5G' 'realme GT 2' 'REDMI Note 12'
#  'REDMI Note 12 5G' 'micromax 3' 'SAMSUNG Galaxy M04' 'REDMI K50i 5G'
#  'MOTOROLA e40' 'REDMI 9 Activ' 'MOTOROLA g42' 'realme C25s'
#  'POCO X5 Pro 5G' 'POCO M3 Pro 5G' 'Infinix Smart 6 HD'
#  'Infinix Hot 20 5G' 'realme C31' 'micromax1' 'OPPO A17' 'realme 9 5G SE'
#  'realme 9i 5G' 'realme C21Y' 'realme Narzo 50i Prime'
#  'REDMI Note 12 Pro 5G' 'Infinix Zero 5G 2023' 'POCO X4 Pro 5G'
#  'MOTOROLA g82 5G' 'REDMI Note 12 Pro+ 5G' 'vivo T1 44W' 'MOTOROLA g31'
#  'realme narzo 50i Prime' 'SAMSUNG Galaxy S22 Plus 5G' 'vivo V27 5G'
#  'realme Narzo 50' 'Infinix HOT 20 Play' 'MOTOROLA g52' 'OPPO A17k'
#  'POCO F5 5G' 'redmi max' 'redmi mono' 'redmi min' 'realme 9 Pro+ 5G'
#  'Infinix Hot 12' 'MOTOROLA g72' 'vivo Y16' 'realme Narzo 50i'
#  'SAMSUNG Galaxy Z Flip3 5G' 'realme C33' 'Infinix Zero 20' 'realme 8'
#  'vivo Y35' 'MOTOROLA Edge 30' 'MOTOROLA Edge 30 Fusion' 'Infinix Note 12'
#  'Google Pixel 7a' 'Tecno Spark 9' 'OPPO Reno8T 5G'
#  'SAMSUNG Galaxy A14 5G' 'POCO C31' 'POCO X2' 'nothing phone 1'
#  'I Kall Z19Pro Flash blue' 'Tecno Spark 9T' 'Infinix Zero 5G 2023 TURBO'
#  'I Kall Z19Pro' 'OPPO A78 5G' 'Tecno Spark Go 2023' 'REDMI 10 Prime 2022'
#  'SAMSUNG Galaxy A23 5G' 'realme C35' 'MOTOROLA g22' 'itel A60'
#  'vivo V23 5G' 'OnePlus Nord 2T 5G' 'MOTOROLA G42' 'Infinix Smart 6'
#  'realme 10 Pro+ 5G' 'realme 9i' 'SAMSUNG Galaxy A34 5G'
#  'realme Narzo N55' 'OPPO A17K' 'Tecno Pop 5 Pro' 'OPPO A77s'
#  'realme C30s' 'MOTOROLA Edge 30 Ultra' 'IQOO Neo 7 5G' 'vivo Y56 5G'
#  'Infinix Note 12 5G' 'Infinix HOT 12 Play' 'vivo Y75'
#  'realme Narzo 50A Prime' 'realme NARZO 50A PRIME' 'Google Pixel 7'
#  'POCO F1' 'vivo Y12G' 'SAMSUNG Galaxy A23' 'realme Narzo 50A'
#  'vivo Y100 5G' 'Redmi 9A Sport' 'REDMI Note 11' 'vivo V25 5G'
#  'SAMSUNG Galaxy S21 FE 5G' 'REDMI Note 11T 5G' 'realme X3 SuperZoom'
#  'OPPO F21 Pro' 'REDMI Note 11S' 'OnePlus 8' 'vivo Y1s' 'OnePlus Nord'
#  'Nokia C01 Plus' 'REDMI 10A SPORT' 'SAMSUNG Galaxy A54 5G' 'vivo Y33s'
#  'REDMI Note 10S' 'APPLE iPhone 11' 'vivo T1 Pro 5G' 'Infinix Smart 5A'
#  'MOTOROLA e22s' 'Infinix Hot 12 Pro' 'REDMI 9i' 'REDMI Note 9'
#  'vivo Y565G' 'SAMSUNG M53 5G' 'REDMI Note 10 Lite' 'APPLE iPhone 14 Plus'
#  'vivo V25 Pro 5G' 'Infinix Hot 11' 'Infinix Note 12 Pro' 'Tecno Pova 3'
#  'REDMI 12c' 'LAVA Z2' 'Infinix Note 11s Free Fire Edition'
#  'realme C11 2021' 'vivo Y21T' 'realme 9 5G' 'SAMSUNG Galaxy A04'
#  'OPPO F21s Pro' 'APPLE iPhone 12' 'SAMSUNG Galaxy A13' 'Nokia G11 Plus'
#  'SAMSUNG Galaxy A04e' 'SAMSUNG Galaxy S23 5G' 'LAVA Z21' 'Tecno Spark 8T'
#  'OPPO A77']

# %%
# Check range for 'Colour'
print(f"Colour: unique values = {data['Colour'].unique()}")
# Out:
# Colour: unique values = ['Night Black' 'Azure Blue' 'Mineral Gray' 'Royal Blue' 'Marigold'
#  'Glacier Blue' 'Mirror Black' 'Diamond White' 'Shadow Black'
#  'Emerald Green' 'Waterfall Blue' 'Opal Green' 'Power Black'
#  'Country Green' 'Cosmic Black' 'Aurora Gold' 'Marine Blue'
#  'Glimmer Black' 'Green Apple' 'Black' 'Light Blue' 'Light Green'
#  'Cool Blue' 'Forest Green' 'Nightsky Green' 'Matte Charcoal' 'Eco Black'
#  'Caribbean Green' 'Jade Purple' 'Satin Silver' 'Sunrise Orange'
#  'Sunrise Copper' 'Arctic Blue' 'Lavender Blue' 'Velocity Wave'
#  'Nitro Blaze' 'Frosted Blue' 'Yellow' 'Midnight Gray' 'Creamy White'
#  'Sandy Gold' 'Aqua Blue' 'GOAT Green' 'Midnight Blue' 'Night Sea'
#  'Bamboo Green' 'Lake Blue' 'Denim Black' 'Wildcat Blue' 'Icy Blue'
#  'Flashy Black' 'Sunshower' 'Rainy Night' 'Rainforest' 'B.A.E. Purple'
#  'Peppy Purple' 'Lucent White' 'Dark Matter' 'Nebula Blue' 'Hyperspace'
#  'Blade Silver' 'Force Black' 'Snowfall' 'Supernova Green' 'Pacific Blue'
#  'OMG Black' 'Eclipse Black' 'Midnight Black' 'Ink Black' 'Silk Blue'
#  'Jade White' 'Racing Silver' 'Alpine White' 'Jaguar Black' 'Rush Black'
#  'Space Black' 'Racing Blue' 'Chalk' 'Charcoal' 'Blaster Green'
#  'Metaverse Blue' 'Steel Black' 'Paper White' 'Clash White' 'Sunrise Gold'
#  'Space Blue' 'Frosted Green' 'Matte Black' 'Mystique Blue' 'Racing Black'
#  'Dark Blue' 'Nebula Green' 'Stealth Black' 'Carbon Gray' 'Coral Green'
#  'Ice Blue' 'Copper Blush' 'Atlantic Green' 'Watery Grey' 'Horizon Blue'
#  'Space Purple' 'Aqua Sky' 'Origin Blue' 'Astral Black' 'Lunar Black'
#  'Dark Green' 'Light Silver' 'Azure Glow' 'Starry Glow' 'Soulful Blue'
#  'Rocking Black' 'Metallica Gold' 'Cross Black' 'Stardust Purple'
#  'Submariner Black' 'Meterorite Grey' 'Iceberg Blue' 'Midnight Galaxy'
#  'Ice Dawn' 'Starry Sky' 'White Lily' 'Baby Blue' 'Obsidian Black'
#  'Mint Green' 'Aurora Green' 'Phantom Black' 'Pearly White' 'Noble Black'
#  'Speed Blue' 'Fantasy Purple' 'Luna Blue' 'Charcoal Grey' 'Speed Black'
#  'Blue' 'Magic Blue' 'Watery Blue' 'Coral Orange' 'Snowstorm White' 'M3)'
#  'Playful Green' 'Onyx Black' 'Silver' 'Arctic White' 'Sunlight Orange'
#  'Exploratory Blue' 'Polar Black' '7Â° Purple' 'Turquoise Cyan'
#  'Meteorite Grey' 'Brown' 'Drizzling Gold' 'Lunar Blue' 'Carbon Black'
#  'Sunrise Blue' 'Green Fantasy' 'DEEP GRAY' 'Punk Black' 'Cyber Black'
#  'Dawn Gold' 'Agate Black' 'Polar Blue' 'Cosmic grey' 'Quick Silver' 'Sea'
#  'Infinity Black' 'Sky Mirror' 'Meteor Grey' 'Dark Red' 'Electric Blue'
#  'Shadow Gray' 'Atlantis Blue' 'Snow' 'White' 'chalk' 'Flash Blue'
#  'Iris Purple' 'Tahiti Gold' 'Steller Black' 'Glowing Black'
#  'Atlantic Blue' 'Laser Black' 'Endless Black' 'Astral White' 'VertMenthe'
#  'Stardust Black' 'Gray Shadow' 'Orange' 'SapphireBlack' 'DawnBlue'
#  'Phantom Blue' 'Metallic Rose' 'Starry Purple' 'Heart Of Ocean'
#  'Light Sea Green' 'Prism Blue' 'Prism Black' 'Awesome Graphite'
#  'Prime Blue' 'Awesome Silver' 'Navy Blue' 'Gold' 'Jade Fog'
#  'Deepsea Luster' 'Sunset Orange' 'Stripe Blue' 'Interstellar Black'
#  'Frost Blue' 'Black Engine' 'Dancing waves' 'Stripe Black' 'Laser Blue'
#  'FLASH BLUE' 'Obsidian' 'Steel Blue' 'Solar Gold' 'Lemongrass'
#  'Orange Shimmer' 'Oxygen Blue' 'Moonlight Shadow' 'Stellar Black'
#  'Metallic White' 'Elegant Black' 'Awesome Violet' 'Olive Green'
#  'Stardust White' 'Surfing Blue' 'Interstellar Glow' 'Aurora Blue'
#  'Glacial Green' 'Blue Marble' 'Starry Black' 'Grey' 'SLATE GREY'
#  'CHARCOAL BLACK' 'Prime Black' 'Flash Black' 'Frost White'
#  'Sunshine Gold' 'Turbo Black' 'Turbo Cyan' 'Uyuni Blue' 'Halo White'
#  'Peach' 'Scarlet Red' 'Starlight White' 'Deep Ocean Blue' 'Glacier White'
#  'Midnight' 'Pure Black' 'Lightsaber Green' 'Sailing Blue' 'Silver Wave'
#  'Tuscany Blue' 'Volcanic Grey' 'Flame Red' 'Oxygen Green'
#  'Aquamarine Blue' 'Matte black' 'Mithril Grey' 'Cool Grey' 'Pearl White'
#  'Nebula Purple' 'Purple' 'UYUNI BLUE' 'Meteor Black' 'Supersonic Black'
#  'Starlight' 'Metal Black' 'Twilight Gold' 'Copper' 'Starlight Black'
#  'Cream' 'Cyan' 'Awesome Lime' 'Sky Blue']

# %%
# Check range for 'Rear Camera'
print(f"Rear Camera: unique values = {data['Rear Camera'].unique()}")
# Out:
# Rear Camera: unique values = ['13MP' '50MP' '8MP' '40MP' '32MP' '48MP' '64MP' '108MP' '0MP' '2MP'
#  '12MP' '200MP' '5MP' '16MP']

# %%
# Check range for 'Front Camera'
print(f"Front Camera: unique values = {data['Front Camera'].unique()}")
# Out:
# Front Camera: unique values = ['5MP' '16MP' '8MP' '13MP' '0MP' '32MP' '10MP' '50MP' '60MP' '20MP' '44MP'
#  '2MP' '12MP']

# %%
# Check range for 'Processor_'
print(f"Processor_: unique values = {data['Processor_'].unique()}")
# Out:
# Processor_: unique values = ['Unisoc Spreadtrum SC9863A1' 'Qualcomm Snapdragon 680'
#  'Mediatek Helio A22' 'G37' 'Exynos 850' 'Mediatek Helio P35' 'Helio G36'
#  'Unisoc T606' 'Dimensity 6020' 'Spreadtrum SC9863A1' 'Mediatek Helio G85'
#  'Helio G85' 'Mediatek Dimensity 700' 'Mediatek Helio G37'
#  'Snapdragon 695' 'Qualcomm Snapdragon 695 5G' 'Mediatek Helio G99'
#  'Unisoc T612' 'Exynos 1330, Octa Core ' 'Mediatek Dimensity 930'
#  'Qualcomm Snapdragon 695' 'Mediatek Helio G96' 'Helio G99' 'Helio G88'
#  'SC6531E' 'Mediatek Dimensity 810' 'MediaTek Dimensity 800U'
#  'Mediatek Dimensity 810 5G' 'Qualcomm Snapdragon 750G' 'Dimensity 8020'
#  'MediaTek Helio G95' 'Mediatek Helio G99 Octa Core' 'MediaTek Helio G96'
#  'MediaTek' 'Google Tensor' 'Dimensity 810' 'Qualcomm Snapdragon 888'
#  'Snapdragon 685' 'Qualcomm Snapdragon 4 Gen 1' '0 0 0 208MHz'
#  'MediaTek Helio P35' 'Dimensity 8100' 'UNISOC T700' 'Mediatek Helio G35'
#  'MediaTek Helio G85' 'Qualcomm Snapdragon 778G' 'MediaTek Dimensity 700'
#  'Unisoc T610' 'Unisoc T612 processor' 'Mediatek Dimensity 1080'
#  'Mediatek Dimensity 920' 'Unisoc Tiger T612 (12 nm)'
#  'Qualcomm Snapdragon 8 Gen 1' 'Mediatek Dimensity 7200 5G' 'MediaTek G37'
#  'Qualcomm Snapdragon 7+ Gen 2 (4nm)' 'Octa Core' 'MT6260A' 'MTK6261D'
#  'Spreadtrum' 'Mediatek MT6261D' 'Meditek Helio G37' 'SC9863A'
#  'Qualcomm Snapdragon 888 Octa-Core' 'Mediatek G99'
#  'Qualcomm Snapdragon 778G Plus' 'Qualcomm Snapdragon 888 +'
#  'MediaTek Helio G88' 'Tensor G2' 'MediaTek Helio G37'
#  'SEC S5E8535 (Exynos 1330)' 'MediaTek Helio G35'
#  'Qualcomm Snapdragon 730G' 'Qualcomm Snapdragon 778G+' 'Android'
#  '2GHz, Quad Core ' 'Qualcomm Snapdragon 695 (SM6375)' 'Unisoc Tiger T616'
#  'Unisoc' 'Oxygen OS' 'Mediatek Dimensity 1080 5G'
#  'Qualcomm Snapdragon 680 (SM6225)' 'Dimensity 1080, Octa Core '
#  'Mediatek Helio G88' 'Helio A22' 'Unisoc SC9863A/ Unisoc SC9863A1'
#  'Qualcomm Snapdragon 8+ Gen 1' 'Snapdragon 8 Gen 1' 'Mediatek G96'
#  'Google Tensor G2' 'Qualcomm Snapdragon 845' 'Qualcomm Snapdragon 439'
#  'Octa-core(EXYNOS)' 'Mediatek Dimensity 900' 'Helio G25' 'Snapdragon 680'
#  'snapdragon 888' 'Qualcomm Snapdragon 855' 'Qualcomm Snapdragon 865'
#  'QualcommÂ® Snapdragonâ_x0084_¢ 765G' 'Unisoc SC9863A'
#  'Exynos 1380, Octa Core ' 'MediaTek Helio G80' 'Mediatek Helio G95'
#  'Qualcomm Snapdragon 855+' 'ios'
#  'Qualcomm Snapdragon 778G 5G Mobile Platform' 'MediaTek Helio A20'
#  'MediaTek G35' 'MediaTek Helio A22' 'Unisoc T616' 'MediaTek Helio G25'
#  'MTK Dimensity 700' 'Qualcomm Snapdragon 720G' 'IOS'
#  'Mediatek Dimensity 1300' 'MediaTek Helio G70' 'Octa-core' '6 Core'
#  'Dimensity 8200' 'Qualcomm SM6225 Snapdragon 680 4G (6 nm)'
#  'Exynos Octa Core' 'Qualcomm Snapdragon 8 Gen 2']

# %%
# Check range for 'Prize'
print(f"Prize: unique values = {data['Prize'].unique()}")
# Out:
# Prize: unique values = ['7,299' '11,999' '5,649' '8,999' '7,999' '9,499' '10,699' '6,999'
#  '15,999' '13,999' '12,999' '6,199' '6,599' '7,749' '9,699' '9,999'
#  '10,999' '20,999' '15,499' '18,999' '12,499' '10,499' '14,490' '16,999'
#  '6,499' '5,999' '6,299' '16,499' '14,499' '13,490' '19,999' '1,449'
#  '1,849' '1,422' '29,999' '1,299' '17,999' '11,499' '2,615' '28,999'
#  '23,999' '14,999' '2,490' '7,961' '2,499' '11,248' '6,799' '13,499'
#  '8,749' '8,049' '1,375' '1,599' '7,499' '7,245' '26,999' '21,999'
#  '17,499' '21,499' '7,115' '49,999' '32,999' '8,499' '25,999' '4,999'
#  '3,549' '1,699' '920' '11,970' '1,199' '12,990' '6,978' '7,370' '44,999'
#  '8,995' '24,999' '11,249' '34,999' '21,174' '43,999' '7,993' '8,069'
#  '30,499' '30,999' '9,290' '8,449' '8,495' '29,499' '20,998' '19,280'
#  '8,649' '19,499' '9,349' '8,288' '12,272' '6,794' '27,540' '27,877'
#  '5,990' '11,980' '11,349' '9,790' '28,298' '22,999' '7,049' '6,960'
#  '9,104' '36,999' '30,385' '19,990' '12,900' '8,990' '10,943' '55,999'
#  '13,489' '11,209' '16,988' '12,989' '7,190' '7,990' '27,999' '19,397'
#  '10,989' '16,990' '29,990' '38,920' '9,387' '29,790' '5,799' '10,890'
#  '10,548' '32,299' '40,999' '11,490' '12,599' '31,989' '41,199' '7,199'
#  '8,940' '19,979' '23,390' '14,385' '80,999' '30,874' '35,999' '10,799'
#  '11,762' '18,990' '29,418' '33,367' '7,280' '34,688' '8,460' '20,890'
#  '53,999' '79,999' '5,998' '9,990' '38,999']

# %% [markdown]
# # **Data Visualization**

# %% [markdown]
# ## **Line Chart:**
# Line graphs are used to track changes over short and long periods of time. When smaller changes exist, line graphs are better to use than bar graphs. Line graphs can also be used to compare changes over the same period of time for more than one group

# %%
#Plot the Data
plt.figure(figsize=(16,6))
sns.lineplot(data=data)
# Out:
# <Axes: >

# %%
#We will begin by printing the names of all columns
list(data.columns)
#We plot the lines corresponding to the first two columns in the dataset.
plt.figure(figsize=(14,6))
plt.title("Battery power by products")
#Line chart shows battery power for the each products
sns.lineplot(data=data['Battery_'], label="Battery Size")
#Line chart shows best price for the each powers
sns.lineplot(data=data['Prize'], label= "Best price")
# Out:
# <Axes: title={'center': 'Battery power by products'}, ylabel='Battery_'>

# %% [markdown]
# ## **Bar Chart**
# - Bar graphs are used to compare things between different groups or to track changes over time. However, when trying to measure change over time, bar graphs are best when the changes are larger.

# %%
#Set the width and height of the figure
plt.figure(figsize=(10,6))
#Add title
plt.title("Average battery power by phone brands")
#Bar chart showing average battery power by phone brands
# Group the data by 'Model' and calculate the mean battery power for each group.
# Then reset the index to convert the result into a DataFrame suitable for plotting.
model_battery = data.groupby('Model')['Battery_'].mean().reset_index()
sns.barplot(x='Model', y='Battery_', data=model_battery)
#Add label for vertical axis
plt.ylabel("battery_size ")
# Out:
# Text(0, 0.5, 'battery_size ')

# %%
import plotly.express as px
fig = px.violin(data, x="Prize", y="RAM", color="Prize", box=True,points = "all")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="855a2a78-755c-4541-aa2d-df3a98a040f9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("855a2a78-755c-4541-aa2d-df3a98a040f9")) {                    Plotly.newPlot(                        "855a2a78-755c-4541-aa2d-df3a98a040f9",                        [{"alignmentgroup":"True","box":{"visible":true},"hovertemplate":"Prize=%{x}\u003cbr\u003eRAM=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"7,299","marker":{"color":"#636efa"},"name":"7,299","offsetgroup":"7,299","orientation":"v","points":"all","scalegroup":"True","showlegend":true,"x":["7,299","7,299","7,299","7,299","7,299","7,299","7,299"],"x0":" ","xaxis":"x","y":[4,4,4,4,4,4,4],"y0":" ","yaxis":"y","type":"violin"},{"alignmentgroup":"True","box":{"visible":true},"hovertemplate":"Prize=%{x}\u003cbr\u003eRAM=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"11,999","marker":{"color":"#EF553B"},"name":"11,999","offsetgroup":"11,999","orientation":"v","points":"all","scalegroup":"True","showlegend":true,"x":["11,999","11,999","11,999","11,999","11,999","11,999","11,999","11,999","11,999","11,999","11,999","11,999","11,999","11,999","11,999"],"x0":" ","xaxis":"x","y":[8,4,8,4,6,6,6,4,6,6,6,4,4,4,4],"y0":" ","yaxis":"y","type":"violin"},{"alignmentgroup":"True","box":{"visible":true},"hovertemplate":"Prize=%{x}\u003cbr\u003eRAM=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"5,649","marker":{"color":"#00cc96"},"name":"5,649","offsetgroup":"5,649","orientation":"v","points":"all","scalegroup":"True","showlegend":true,"x":["5,649","5,649"],"x0":" ","xaxis":"x","y":[2,2],"y0":" ","yaxis":"y","type":"violin"},{"alignmentgroup":"True","box":{"visible":true},"hovertemplate":"Prize=%{x}\u003cbr\u003eRAM=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"8,999","marker":{"color":"#ab63fa"},"name":"8,999","offsetgroup":"8,999","orientation":"v","points":"all","scalegroup":"True","showlegend":true,"x":["8,999","8,999","8,999","8,999","8,999","8,999","8,999","8,999","8,999","8,999","8,999","8,999","8,999","8,999","8,999","8,999","8,999","8,999","8,999","8,999"],"x0":" ","xaxis":"x","y":[8,8,8,8,6,6,4,4,4,4,4,3,3,4,4,4,4,4,4,4],"y0":" ","yaxis":"y","type":"violin"},{"alignmentgroup":"True","box":{"visible":true},"hovertemplate":"Prize=%{x}\u003cbr\u003eRAM=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"7,999","marker":{"color":"#FFA15A"},"name":"7,999","offsetgroup":"7,999","orientation":"v","points":"all","scalegroup":"True","showlegend":true,"x":["7,999","7,999","7,999","7,999","7,999","7,999","7,999","7,999","7,999","7,999"],"x0":" ","xaxis":"x","y":[4,4,4,4,4,4,4,4,4,3],"y0":" ","yaxis":"y","type":"violin"},{"alignmentgroup":"True","box":{"visible":true},"hovertemplate":"Prize=%{x}\u003cbr\u003eRAM=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"9,499","marker":{"color":"#19d3f3"},"name":"9,499","offsetgroup":"9,499","orientation":"v","points":"all","scalegroup":"True","showlegend":true,"x":["9,499","9,499","9,499","9,499","9,499","9,499","9,499","9,499","9,499","9,499","9,499"],"x0":" ","xaxis":"x","y":[4,4,4,4,6,3,4,4,3,3,6],"y0":" ","yaxis":"y","type":"violin"},{"alignmentgroup":"True","box":{"visible":true},"hovertemplate":"Prize=%{x}\u003cbr\u003eRAM=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"10,699","marker":{"color":"#FF6692"},"name":"10,699","offsetgroup":"10,699","orientation":"v","points":"all","scalegroup":"True","showlegend":true,"x":["10,699","10,699","10,699","10,699"],"x0":" ","xaxis":"x","y":[4,4,4,4],"y0":" ","yaxis":"y","type":"violin"},{"alignmentgroup":"True","box":{"visible":true},"hovertemplate":"Prize=%{x}\u003cbr\u003eRAM=%{y}\u003cextra\u003e\u003c\u002fextra\u003e" ...

# %%
fig = px.scatter_3d(data, x='RAM', y='Memory', z='Prize',
              color='Prize')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f9fc3816-2eb4-485b-8400-45d8c5fdce4e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f9fc3816-2eb4-485b-8400-45d8c5fdce4e")) {                    Plotly.newPlot(                        "f9fc3816-2eb4-485b-8400-45d8c5fdce4e",                        [{"hovertemplate":"Prize=%{z}\u003cbr\u003eRAM=%{x}\u003cbr\u003eMemory=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"7,299","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"7,299","scene":"scene","showlegend":true,"x":[4,4,4,4,4,4,4],"y":[64,64,64,64,64,64,64],"z":["7,299","7,299","7,299","7,299","7,299","7,299","7,299"],"type":"scatter3d"},{"hovertemplate":"Prize=%{z}\u003cbr\u003eRAM=%{x}\u003cbr\u003eMemory=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"11,999","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"11,999","scene":"scene","showlegend":true,"x":[8,4,8,4,6,6,6,4,6,6,6,4,4,4,4],"y":[128,64,128,64,64,64,64,64,128,128,128,64,64,64,64],"z":["11,999","11,999","11,999","11,999","11,999","11,999","11,999","11,999","11,999","11,999","11,999","11,999","11,999","11,999","11,999"],"type":"scatter3d"},{"hovertemplate":"Prize=%{z}\u003cbr\u003eRAM=%{x}\u003cbr\u003eMemory=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"5,649","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"5,649","scene":"scene","showlegend":true,"x":[2,2],"y":[32,32],"z":["5,649","5,649"],"type":"scatter3d"},{"hovertemplate":"Prize=%{z}\u003cbr\u003eRAM=%{x}\u003cbr\u003eMemory=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"8,999","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"8,999","scene":"scene","showlegend":true,"x":[8,8,8,8,6,6,4,4,4,4,4,3,3,4,4,4,4,4,4,4],"y":[128,128,128,128,128,128,64,64,64,64,64,32,32,64,64,64,64,64,64,64],"z":["8,999","8,999","8,999","8,999","8,999","8,999","8,999","8,999","8,999","8,999","8,999","8,999","8,999","8,999","8,999","8,999","8,999","8,999","8,999","8,999"],"type":"scatter3d"},{"hovertemplate":"Prize=%{z}\u003cbr\u003eRAM=%{x}\u003cbr\u003eMemory=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"7,999","marker":{"color":"#FFA15A","symbol":"circle"},"mode":"markers","name":"7,999","scene":"scene","showlegend":true,"x":[4,4,4,4,4,4,4,4,4,3],"y":[64,64,64,64,64,64,64,64,64,32],"z":["7,999","7,999","7,999","7,999","7,999","7,999","7,999","7,999","7,999","7,999"],"type":"scatter3d"},{"hovertemplate":"Prize=%{z}\u003cbr\u003eRAM=%{x}\u003cbr\u003eMemory=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"9,499","marker":{"color":"#19d3f3","symbol":"circle"},"mode":"markers","name":"9,499","scene":"scene","showlegend":true,"x":[4,4,4,4,6,3,4,4,3,3,6],"y":[64,64,64,64,128,64,64,64,64,64,128],"z":["9,499","9,499","9,499","9,499","9,499","9,499","9,499","9,499","9,499","9,499","9,499"],"type":"scatter3d"},{"hovertemplate":"Prize=%{z}\u003cbr\u003eRAM=%{x}\u003cbr\u003eMemory=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"10,699","marker":{"color":"#FF6692","symbol":"circle"},"mode":"markers","name":"10,699","scene":"scene","showlegend":true,"x":[4,4,4,4],"y":[128,128,128,128],"z":["10,699","10,699","10,699","10,699"],"type":"scatter3d"},{"hovertemplate":"Prize=%{z}\u003cbr\u003eRAM=%{x}\u003cbr\u003eMemory=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"6,999","marker":{"color":"#B6E880","symbol":"circle"},"mode":"markers","name":"6,999","scene":"scene","showlegend":true,"x":[4,4,2,2,2,2,2,2,2],"y":[64,64,32,64,64,64,64,32,32],"z":["6,999","6,999","6,999","6,999","6,999","6,999","6,999","6,999","6,999"],"type":"scatter3d"},{"hovertemplate":"Prize=%{z}\u003cbr\u003eRAM=%{x}\u003cbr\u00 ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Model', 'Colour', 'Memory', 'RAM', 'Battery_',
#        'Rear Camera', 'Front Camera', 'AI Lens', 'Mobile Height', 'Processor_',
#        'Prize'],
#       dtype='object')

# %% [markdown]
# What are the most popular Model?

# %%
brand_counts = data['Model'].value_counts()

# Get the most popular brand
most_popular_brand = brand_counts.idxmax()

# Set Seaborn style
sns.set(style="darkgrid")

# Create the plot
plt.figure(figsize=(8, 6))
plot = sns.catplot(x='Model', kind='count', data=data, palette="Dark2")
plot.fig.suptitle("Count of Each Brand")

# Highlight the most popular brand
plot.axes[0, 0].axhline(y=brand_counts[most_popular_brand], color='red', linestyle='--', label=f'Most Popular: {most_popular_brand}')
plt.legend()

# Rotate x-axis labels vertically
plt.xticks(rotation=90, ha='center')

plt.show()
# Out:
# <ipython-input-39-6b25798cf715>:11: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %% [markdown]
# Whar are model with high storage ?

# %%
fig = px.violin(data, x="Processor_", y="Battery_", color="Prize",violinmode="overlay")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b7d88249-8358-4bf0-baaa-a4bf1f50ca31" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b7d88249-8358-4bf0-baaa-a4bf1f50ca31")) {                    Plotly.newPlot(                        "b7d88249-8358-4bf0-baaa-a4bf1f50ca31",                        [{"alignmentgroup":"True","box":{"visible":false},"hovertemplate":"Prize=7,299\u003cbr\u003eProcessor_=%{x}\u003cbr\u003eBattery_=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"7,299","marker":{"color":"#636efa"},"name":"7,299","offsetgroup":"7,299","orientation":"v","scalegroup":"True","showlegend":true,"x":["Unisoc Spreadtrum SC9863A1","Unisoc Spreadtrum SC9863A1","Unisoc Spreadtrum SC9863A1","Mediatek Helio P35","Unisoc T606","Mediatek Helio P35","Unisoc T606"],"x0":" ","xaxis":"x","y":[6000,6000,6000,5000,5000,5000,5000],"y0":" ","yaxis":"y","type":"violin"},{"alignmentgroup":"True","box":{"visible":false},"hovertemplate":"Prize=11,999\u003cbr\u003eProcessor_=%{x}\u003cbr\u003eBattery_=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"11,999","marker":{"color":"#EF553B"},"name":"11,999","offsetgroup":"11,999","orientation":"v","scalegroup":"True","showlegend":true,"x":["Qualcomm Snapdragon 680","Mediatek Dimensity 700","Qualcomm Snapdragon 680","Mediatek Dimensity 700","Helio G88","Helio G88","Helio G88","Mediatek Dimensity 700","Helio G99","Helio G99","Helio G99","Mediatek Helio P35","Mediatek Helio P35","Qualcomm Snapdragon 680 (SM6225)","Mediatek Helio G85"],"x0":" ","xaxis":"x","y":[5000,5000,5000,5000,5000,5000,5000,5000,5000,5000,5000,5000,5000,5000,5000],"y0":" ","yaxis":"y","type":"violin"},{"alignmentgroup":"True","box":{"visible":false},"hovertemplate":"Prize=5,649\u003cbr\u003eProcessor_=%{x}\u003cbr\u003eBattery_=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"5,649","marker":{"color":"#00cc96"},"name":"5,649","offsetgroup":"5,649","orientation":"v","scalegroup":"True","showlegend":true,"x":["Mediatek Helio A22","Mediatek Helio A22"],"x0":" ","xaxis":"x","y":[5000,5000],"y0":" ","yaxis":"y","type":"violin"},{"alignmentgroup":"True","box":{"visible":false},"hovertemplate":"Prize=8,999\u003cbr\u003eProcessor_=%{x}\u003cbr\u003eBattery_=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"8,999","marker":{"color":"#ab63fa"},"name":"8,999","offsetgroup":"8,999","orientation":"v","scalegroup":"True","showlegend":true,"x":["G37","G37","G37","G37","Mediatek Helio G85","Mediatek Helio G85","UNISOC T700","Meditek Helio G37","Meditek Helio G37","Meditek Helio G37","Meditek Helio G37","Unisoc T612","Unisoc T612","MediaTek Helio G35","Unisoc T610","Unisoc T610","MediaTek G35","MediaTek G35","MediaTek Helio G25","Mediatek Helio A22"],"x0":" ","xaxis":"x","y":[5000,5000,5000,5000,5000,5000,5000,6000,6000,6000,6000,5000,5000,5000,6000,6000,5000,5000,5000,5000],"y0":" ","yaxis":"y","type":"violin"},{"alignmentgroup":"True","box":{"visible":false},"hovertemplate":"Prize=7,999\u003cbr\u003eProcessor_=%{x}\u003cbr\u003eBattery_=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"7,999","marker":{"color":"#FFA15A"},"name":"7,999","offsetgroup":"7,999","orientation":"v","scalegroup":"True","showlegend":true,"x":["G37","G37","G37","G37","Mediatek Helio G37","Mediatek Helio G37","Mediatek Helio G37","Octa Core","Octa Core","MediaTek Helio G35"],"x0":" ","xaxis":"x","y":[5000,5000,5000,5000,5000,5000,5000,5000,5000,5000],"y0":" ","yaxis":"y","type":"violin"},{"alignmentgroup":"True","box":{"visible":false},"hovertemplate":"Prize=9,499\u003cbr\u003eProcessor_=%{x}\u003cbr\u003eBattery_=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"9,499","marker":{"color":"#19d3f3"},"name":"9,499","offsetgroup":"9,499","orientation ...

# %% [markdown]
# # **Scatter Plots**
# - In a scatter plot, the values of 2 variables are plotted as points on a 2-dimensional grid. Additonally, you can also use a third variable to determine the size or color of the points.

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Model', 'Colour', 'Memory', 'RAM', 'Battery_',
#        'Rear Camera', 'Front Camera', 'AI Lens', 'Mobile Height', 'Processor_',
#        'Prize'],
#       dtype='object')

# %%
import seaborn as sns
sns.scatterplot(x=data['Memory'],
               y=data['Prize'])
# Out:
# <Axes: xlabel='Memory', ylabel='Prize'>

# %% [markdown]
# **To double-check the strength of this relationship, you might like to add a regression line, or the line best fits the data. We do this by changing the command to sns.regplot**

# %% [markdown]
# **Color-Coded scatter plots**
# We can use scatter plots to display the relationship between three variables. One way of doing this is by color_coding the points.

# %%
sns.scatterplot(x=data['Memory'],
               y=data['Prize'], hue = data['RAM'])
# Out:
# <Axes: xlabel='Memory', ylabel='Prize'>

# %% [markdown]
# # **Histogram**

# %%
# Visualize data using histograms
for column in num_col:
    plt.figure(figsize=(8, 6))
    plt.hist(data[column], bins=20, edgecolor='k', alpha=0.7)
    plt.title(f'Histogram for {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.grid(True)
    plt.show()

# %% [markdown]
# ## **Box Plot**

# %%
#  Create the plot grid
rows = 3
columns = 2

fig, axes = plt.subplots(rows,columns, figsize=(30,30))

x, y = 0, 0

for i, column in enumerate(num_col):
    sns.boxplot(x=data[column], ax=axes[x, y])

    if y < columns-1:
        y += 1
    elif y == columns-1:
        x += 1
        y = 0
    else:
        y += 1

        plt.show()

# %%
# Visualizing the Numerical Features by boxplots
sns.set_style('darkgrid')
def boxplots_custom(dataset, columns_list, rows, cols, suptitle):
    fig, axs = plt.subplots(rows, cols, sharey=True, figsize=(15,7))
    fig.suptitle(suptitle, y=1, size=25)
    axs = axs.flatten()
    for i, data in enumerate(columns_list):
        sns.boxplot(data=dataset[data], orient='h', color ='#6fcfbc', ax=axs[i])
        axs[i].set_title(data + ', skewness is: '+str(round(dataset[data].skew(axis = 0, skipna = True), 2)))

boxplots_custom(dataset=data, columns_list=num_col, rows=2, cols=3, suptitle='Boxplots for each variable')
plt.tight_layout()

# %% [markdown]
# # **Data Cleaning:**

# %% [markdown]
# **Missing Values**

# %%
data.isnull().sum()
# Out:
# Unnamed: 0       0
# Model            0
# Colour           0
# Memory           0
# RAM              0
# Battery_         0
# Rear Camera      0
# Front Camera     0
# AI Lens          0
# Mobile Height    0
# Processor_       0
# Prize            0
# dtype: int64

# %%
# Missing values
plt.figure(figsize=(22,4))
sns.heatmap((data.isna().sum()).to_frame(name='').T,cmap='GnBu', annot=True,
             fmt='0.0f').set_title('Count missing values', fontsize=18)
plt.show()

# %%
# Check for duplicates
data.duplicated().sum()
# Out:
# 0

# %%
# Remove duplicates in-place
data.drop_duplicates(inplace=True)

# %%
# Handle missing values
data['Memory'] = data['Memory'].fillna(data['Memory'].mean())
data['Battery_'] = data['Battery_'].fillna(data['Battery_'].mean())
data['AI Lens'] = data['AI Lens'].fillna(data['AI Lens'].median())
data['Mobile Height'] = data['Mobile Height'].fillna(data['Mobile Height'].median())

# %%
# Check for remaining missing values
missing_values = data.isnull().sum()
print(missing_values)
# Out:
# Unnamed: 0       0
# Model            0
# Colour           0
# Memory           0
# RAM              0
# Battery_         0
# Rear Camera      0
# Front Camera     0
# AI Lens          0
# Mobile Height    0
# Processor_       0
# Prize            0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
# Drop the "Unnamed: 0" column
data = data.drop(columns=['Unnamed: 0'])

# %%
# Save the cleaned data back to a CSV file
cleaned_file_path = 'Cleaned_Flipdata.csv'
data.to_csv(cleaned_file_path, index=False)

# %%
data.columns
# Out:
# Index(['Model', 'Colour', 'Memory', 'RAM', 'Battery_', 'Rear Camera',
#        'Front Camera', 'AI Lens', 'Mobile Height', 'Processor_', 'Prize'],
#       dtype='object')

# %%
num_cols=data.select_dtypes(include=['int64', 'float'])

# %% [markdown]
# ## **Detect Outliers**

# %%
# Calculate the IQR for each column in the dataset
Q1 = num_cols.quantile(0.25)
Q3 = num_cols.quantile(0.75)
IQR = Q3 - Q1

# Identify outliers using the IQR method
outliers = ((num_cols < (Q1 - 1.5 * IQR)) | (num_cols > (Q3 + 1.5 * IQR)))

# Count the number of outliers for each variable
num_outliers = outliers.sum()

# Number of outliers for each variable
num_outliers.to_frame().T
# Out:
#    Memory  RAM  Battery_  AI Lens  Mobile Height
# 0      55    0       152       34             33

# %% [markdown]
# ## **Remove Outliers**

# %%
# Function to remove outliers from a column using IQR method
def remove_outliers(column):
    Q1 = column.quantile(0.25)
    Q3 = column.quantile(0.75)
    IQR = Q3 - Q1
    return column[(column >= Q1 - 1.5 * IQR) & (column <= Q3 + 1.5 * IQR)]

# Dictionary to store information about removed outliers
removed_outliers_info = {}

# Iterate over each numerical column
for column in data.select_dtypes(include=['float64', 'int64']).columns:
    # Count rows before outlier removal
    rows_before = data[column].dropna().shape[0]

    # Remove outliers from the column
    cleaned_column = remove_outliers(data[column])

    # Store cleaned column back into the DataFrame
    data[column] = cleaned_column

    # Count rows after outlier removal
    rows_after = cleaned_column.dropna().shape[0]

    # Calculate number of outliers removed
    outliers_removed = rows_before - rows_after

    # Store information about removed outliers
    removed_outliers_info[column] = outliers_removed

# Create a DataFrame from the removed_outliers_info dictionary
removed_outliers_df = pd.DataFrame(list(removed_outliers_info.items()), columns=['Column', 'Outliers_Removed'])

# Display the DataFrame with removed outliers information
removed_outliers_df.T
# Out:
#                        0    1         2        3              4
# Column            Memory  RAM  Battery_  AI Lens  Mobile Height
# Outliers_Removed      55    0       152       34             33

# %%
# Save the cleaned data to a CSV file
cleaned_data_file_path = 'cleaned_data_with_no_outliers.csv'
data.to_csv(cleaned_data_file_path, index=False)

print(f"Cleaned data saved to {cleaned_data_file_path}")
# Out:
# Cleaned data saved to cleaned_data_with_no_outliers.csv

# %%
# Calculate the correlation matrix
correlation_matrix=num_col.corr()
correlation_matrix
# Create a heatmap for the num cols
plt.figure(figsize=(10, 8))
sns.heatmap(num_col.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()

# %%
#Check noises by pairplot
sns.set_palette('crest')
sns.set_style('darkgrid')
# Convert num_cols to a list
dnp = sns.pairplot(data, vars=num_cols.columns.tolist())

# Add axis labels and tick labels to the plot
dnp.set(xticklabels=[], yticklabels=[])
dnp.axes[0][0].set_ylabel(num_cols.columns.tolist()[0], fontsize=14)
dnp.axes[-1][0].set_xlabel(num_cols.columns.tolist()[0], fontsize=14)
dnp.axes[-1][0].xaxis.labelpad = 20
dnp.axes[-1][-1].yaxis.labelpad = 20

# Title of the plot
dnp.fig.suptitle('Pairplot for each variable\n(Range: min={}, max={})'.format(data[num_cols.columns].min().min(), data[num_cols.columns].max().max()), y=1.03, fontsize=25)

# Show the plot
plt.show()

# %% [markdown]
# # **Data Preprocessing**

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# %%
# Impute missing values for numerical features with the mean

numerical_features = data.select_dtypes(include=['int64', 'float64']).columns
categorical_features = data.select_dtypes(include=['object']).columns

# %%
# Impute missing values for categorical features with the most frequent value
numerical_transformer = SimpleImputer(strategy='mean')
categorical_transformer = SimpleImputer(strategy='most_frequent')

# %% [markdown]
# **Feature Scaling**
# - **Normalize/Standardize Numerical Features**

# %%
# Standardize numerical features
scaler = StandardScaler()

# %% [markdown]
# ### **Encode Categorical Features**

# %% [markdown]
# **Convert categorical variables (e.g., model, colour) into a suitable numerical format, such as one-hot encoding.**

# %%
# Identify columns of type 'object' (categorical)
categorical_cols = data.select_dtypes(include=['object']).columns

# Apply one-hot encoding to categorical columns
data_encoded = pd.get_dummies(data, columns=categorical_cols)

# %%
data_encoded
# Out:
#      Memory  RAM  Battery_  AI Lens  Mobile Height  Model_APPLE iPhone 11  \
# 0      64.0    4       NaN      NaN          16.76                  False
# 1      64.0    4       NaN      NaN          16.76                  False
# 2     128.0    8    5000.0      0.0          16.64                  False
# 3      32.0    2    5000.0      0.0          16.56                  False
# 4     128.0    8    5000.0      NaN          16.76                  False
# ..      ...  ...       ...      ...            ...                    ...
# 536     NaN    8       NaN      0.0            NaN                  False
# 537    32.0    2       NaN      0.0            NaN                  False
# 538    64.0    4    5000.0      0.0          16.76                  False
# 539   128.0    8    5000.0      0.0          16.26                  False
# 540   128.0    4    5000.0      0.0          16.66                  False
#
#      Model_APPLE iPhone 12  Model_APPLE iPhone 14 Plus  Model_Google Pixel 6a  \
# 0                    False                       False                  False
# 1                    False                       False                  False
# 2                    False                       False                  False
# 3                    False                       False                  False
# 4                    False                       False                  False
# ..                     ...                         ...                    ...
# 536                  False                       False                  False
# 537                  False                       False                  False
# 538                  False                       False                  False
# 539                  False                       False                  False
# 540                  False                       False                  False
#
#      Model_Google Pixel 7  ...  Prize_9,104  Prize_9,290  Prize_9,349  \
# 0                   False  ...        False        False        False
# 1                   False  ...        False        False        False
# 2                   False  ...        False        False        False
# 3                   False  ...        False        False        False
# 4                   False  ...        False        False        False
# ..                    ...  ...          ...          ...          ...
# 536                 False  ...        False        False        False
# 537                 False  ...        False        False        False
# 538                 False  ...        False        False        False
# 539                 False  ...        False        False        False
# 540                 False  ...        False        False        False
#
#      Prize_9,387  Prize_9,499  Prize_9,699  Prize_9,790  Prize_9,990  \
# 0          False        False        False        False        False
# 1          False        False        False        False        False
# 2          False        False        False        False        False
# 3          False        False        False        False        False
# 4          False        False        False        False        False
# ..           ...          ...          ...          ...          ...
# 536        False        False        False        False        False
# 537        False        False        False        False        False
# 538        False        False        False        False         True
# 539        False        False        False        False        False
# 540        False        False        False        False        False
#
#      Prize_9,999  Prize_920
# 0          False      False
# 1          False      False
# 2          False      False
# 3          False      False
# 4          False      False
# ..           ...        ...
# 536        False      False
# 537        False      False
# 538        False      False
# 539        False      False
# 540        False      False
#
# [541 rows x 775 columns]

# %%
# Assume 'prize' is the target variable
X = data.drop('Prize', axis=1)
y = data['Prize']

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Fit and transform the training data
X_train_preprocessed = preprocessor.fit_transform(X_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-82-a764d0410516> in <cell line: 2>()
#       1 # Fit and transform the training data
# ----> 2 X_train_preprocessed = preprocessor.fit_transform(X_train)
#
# NameError: name 'preprocessor' is not defined

# %%
# Transform the testing data
X_test_preprocessed = preprocessor.transform(X_test)

# %% [markdown]
# # **Feature Extraction**

# %% [markdown]
# # **1. Missing Value Ratio**

# %%
# Calculate the percentage of missing values for each feature
missing_ratio = data.isnull().mean()

# Display the missing value ratio
print("Missing Value Ratio:\n", missing_ratio)
# Out:
# Missing Value Ratio:
#  Model            0.000000
# Colour           0.000000
# Memory           0.101664
# RAM              0.000000
# Battery_         0.280961
# Rear Camera      0.000000
# Front Camera     0.000000
# AI Lens          0.062847
# Mobile Height    0.060998
# Processor_       0.000000
# Prize            0.000000
# dtype: float64

# %% [markdown]
# **Remove Features with High Missing Value Ratio.**

# %%
# Set a threshold for missing values (e.g., 30%)
threshold = 0.30

# Select features that have a missing value ratio below the threshold
features_to_keep = missing_ratio[missing_ratio < threshold].index

# Create a new dataframe with selected features
data_reduced = data[features_to_keep]

# Display the reduced dataframe
data_reduced
# Out:
#                      Model          Colour  Memory  RAM  Battery_ Rear Camera  \
# 0          Infinix SMART 7     Night Black    64.0    4       NaN        13MP
# 1          Infinix SMART 7      Azure Blue    64.0    4       NaN        13MP
# 2             MOTOROLA G32    Mineral Gray   128.0    8    5000.0        50MP
# 3                 POCO C50      Royal Blue    32.0    2    5000.0         8MP
# 4          Infinix HOT 30i        Marigold   128.0    8    5000.0        50MP
# ..                     ...             ...     ...  ...       ...         ...
# 536  SAMSUNG Galaxy S23 5G           Cream     NaN    8       NaN        50MP
# 537               LAVA Z21            Cyan    32.0    2       NaN         5MP
# 538         Tecno Spark 8T  Turquoise Cyan    64.0    4    5000.0        50MP
# 539  SAMSUNG Galaxy A54 5G    Awesome Lime   128.0    8    5000.0        50MP
# 540               OPPO A77        Sky Blue   128.0    4    5000.0        50MP
#
#     Front Camera  AI Lens  Mobile Height                   Processor_   Prize
# 0            5MP      NaN          16.76   Unisoc Spreadtrum SC9863A1   7,299
# 1            5MP      NaN          16.76   Unisoc Spreadtrum SC9863A1   7,299
# 2           16MP      0.0          16.64      Qualcomm Snapdragon 680  11,999
# 3            5MP      0.0          16.56           Mediatek Helio A22   5,649
# 4            5MP      NaN          16.76                          G37   8,999
# ..           ...      ...            ...                          ...     ...
# 536         12MP      0.0            NaN  Qualcomm Snapdragon 8 Gen 2  79,999
# 537          2MP      0.0            NaN                    Octa Core   5,998
# 538          8MP      0.0          16.76           MediaTek Helio G35   9,990
# 539         32MP      0.0          16.26      Exynos 1380, Octa Core   38,999
# 540          8MP      0.0          16.66           Mediatek Helio G35  15,999
#
# [541 rows x 11 columns]

# %% [markdown]
# # **LDA (Linear Discriminant Analysis)**

# %% [markdown]
# Linear Discriminant Analysis (LDA) is most commonly used as dimensionality reduction technique in the pre-processing step for pattern-classification and machine learning applications. The goal is to project a dataset onto a lower-dimensional space with good class-separability in order avoid overfitting (“curse of dimensionality”) and also reduce computational costs.

# %% [markdown]
# # **Univarient Feature Selection**

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
data.shape
# Out:
# (541, 11)

# %%
cat_col.columns
# Out:
# Index(['Model', 'Colour', 'Rear Camera', 'Front Camera', 'Processor_',
#        'Prize'],
#       dtype='object')

# %%
from sklearn.impute import SimpleImputer
 #Identify categorical columns
categorical_columns = X.select_dtypes(include=['object']).columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-70-37175b95c06e> in <cell line: 3>()
#       1 from sklearn.impute import SimpleImputer
#       2  #Identify categorical columns
# ----> 3 categorical_columns = X.select_dtypes(include=['object']).columns
#       4
#
# NameError: name 'X' is not defined

# %%
# Apply one-hot encoding
X_encoded = pd.get_dummies(X, columns=categorical_columns)

# %%
# Handle missing values
imputer = SimpleImputer(strategy='mean')  # You can also use 'median' or 'most_frequent'
X_imputed = imputer.fit_transform(X_encoded)

# %%
# Apply SelectKBest with chi2
ordered_rank_features = SelectKBest(score_func=chi2, k=20)
ordered_feature = ordered_rank_features.fit(X_imputed, y)

# %%
# Create a DataFrame to hold feature scores
dfscores = pd.DataFrame(ordered_feature.scores_, columns=["Score"])

# %%
# Create a DataFrame to hold feature names
dfcolumns = pd.DataFrame(X_encoded.columns, columns=["Features"])

# %%
# Concatenate DataFrames to create a ranked feature list
features_rank = pd.concat([dfcolumns, dfscores], axis=1)

# %%
# Rename columns for clarity
features_rank.columns = ['Features', 'Score']

# %%
# Display the ranked features
features_rank

# %%
features_rank.nlargest(10,'Score')

# %% [markdown]
# Feature Importance
# This technique gives you a score for each feature of your data,the higher the score mor relevant it is

# %% [markdown]
# # **Filter Methods**
# - Filter methods evaluate the intrinsic properties of the features based on univariate statistics and do not involve any machine learning model. These methods are fast and computationally efficient, making them suitable for high-dimensional data.

# %%
from sklearn.feature_selection import mutual_info_classif

# Assuming X and y are your features and target variable
information_gain = mutual_info_classif(X_imputed, y)

# %%
information_gain

# %% [markdown]
# # **Fisher’s Score:**
#
# Ranks variables based on their Fisher score, which measures the separation between classes.

# %%
# !pip install skfeature

# %%
import numpy as np

def fisher_score(X, y):
    classes = np.unique(y)
    fisher_scores = []
    for feature in X.T:
        numerator = 0
        denominator = 0
        overall_mean = np.mean(feature)
        for c in classes:
            class_feature = feature[y == c]
            class_mean = np.mean(class_feature)
            class_variance = np.var(class_feature)
            numerator += len(class_feature) * (class_mean - overall_mean) ** 2
            denominator += len(class_feature) * class_variance
        fisher_scores.append(numerator / denominator)
    return np.array(fisher_scores)

fisher_scores = fisher_score(X.values, y.values)
fisher_score_df = pd.DataFrame({'Feature': X.columns, 'Fisher Score': fisher_scores})
fisher_score_df = fisher_score_df.sort_values(by='Fisher Score', ascending=False)
print(fisher_score_df)

# %% [markdown]
# # **Correlation Coefficient:**
#
# Measures the linear relationship between features and the target.
# High correlation with the target but low correlation among features is desired.
